# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/AgrimJain-quantum/internship-remote/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
Machine Learning

I chose the Machine Learning lane because I want to build data-driven systems that solve real-world decision problems instead of relying on manually written rules.
As an Electrical and Electronics Engineering student transitioning into AI/ML, I have already worked on machine learning projects such as electricity load forecasting,
where I learned how data preprocessing, feature engineering, model training, and evaluation improve prediction quality.
This project gives me the opportunity to understand how production ML systems are built and how learned models can outperform simple heuristics.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
The goal is to improve the decision of whether a search result should be recommended or ranked higher for a user.
The recommendation system or search ranking model acts on this decision.
A correct recommendation helps users quickly find relevant information, while an incorrect recommendation may hide useful results, reduce user satisfaction, and increase the time required to complete a search.
Poor recommendations at scale can also reduce user engagement and trust in the platform.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
The starter dataset contains approximately <number_of_rows> search examples with <number_of_columns> features.
Around <positive_percentage>% of the examples belong to the positive class.
These numbers show that the dataset is large enough for meaningful machine learning experiments and that understanding the class distribution will be important when selecting evaluation metrics.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
This project can identify patterns in historical search data and estimate which search results are more likely to be useful.
It can support ranking decisions by learning from previous examples and comparing its performance with rule-based approaches.
However, it cannot prove causal relationships or guarantee that a recommendation is always correct.
 The model provides statistical predictions based on the available data and should be treated as a decision-support system rather than a perfect replacement for human judgment.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
